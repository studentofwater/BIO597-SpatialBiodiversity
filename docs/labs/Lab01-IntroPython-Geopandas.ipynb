# %% [markdown]
# # Introduction to Python and Geopandas
#
# ## BIO597 Spatial Analysis of Biodiversity Fall 2026
#
# ## Goals for today
# This notebook is intended to introduce you to the basic workflow of using Python within Jupyter notebooks,
# using geopandas and species occurrence data as the motivating examples.
#
# Here are some basic expectations for labs/assignments:
# * I do **not** expect you to be python/programming experts coming into this class
# * We will introduce and reinforce programming concepts gradually
#
# ### What are Jupyter Notebooks and why would I want to use one?
# Jupyter notebooks are a great way to generate reproducible scientific analysis workflows in python. You can mix documentation, code, tables, and figures in one executable document which can easily be shared and published to the web. It's very common to organize/share notebooks in github. Here is a good example of a notebook demonstrating a method I am developing called [Multispecies EstimAtion of Dispersal On netWorks (Meadow)](https://github.com/isaacovercast/meadow/blob/main/notebooks/Community-Meadow.ipynb).
#
# Let's get started.

# %% [markdown]
# #### This is your first markdown cell
#
# Try running this cell by pressing the 'play' button in the toolbar above. What happens?
#
# Markdown cells contain formatted text instead of Python code. They are useful for notes, explanations, headings, links, and instructions.

# %%
# This is your first actual code cell.

# python uses the pound sign ('#') to indicate a comment line (lines that will be ignored when running the code).

# Imports
# It's very standard to have the first code cell in a notebook import any needed packages

# Here we import geopandas, a simple python geospatial analysis package. 
# Saying 'as gpd' creates a synonym, so we can call
# functions from this package using the shorter name (saves typing).
import geopandas as gpd
# We also import the standard pandas python library for manipulating tabular data
import pandas as pd

# %% [markdown]
# ## Species occurrence records
#
# Data for this exercise is from [Harrington et al 2024 "Pleistocene Glaciation Drove Shared Population Coexpansion in Eastern North American Snakes"](https://onlinelibrary.wiley.com/doi/10.1111/mec.17625)
#
# The `EasternSnakes` folder contains simple CSV files of occurrence records for several snake species. Each row is one record, with an `ID`, `Longitude`, and `Latitude`.
#
# A CSV is just a table, so we will first read it with `pandas`, then convert it to a `GeoDataFrame` by turning the longitude and latitude columns into point geometries.

# %%
sdekayi_csv = "EasternSnakes/Sdekayi_coords.csv"
sdekayi_df = gpd.read_file(sdekayi_csv)
sdekayi_df.head()
# Out:
#           ID     Longitude     Latitude
# 0  CAS162020     -79.53386     33.14123
# 1  CAS199805  -82.80616589  41.54882969
# 2  CAS210409  -79.24691667  41.18311667
# 3   OMNH2693     -94.52158     34.69291
# 4  OMNH12346    -97.449726     35.17868

# %% [markdown]
# ### Convert the table to a GeoDataFrame
#
# We will start with DeKay's brownsnake (*Storeria dekayi*). The important step is `points_from_xy`, which creates point geometries from the longitude and latitude columns.
#
# The coordinate reference system, or CRS, is `EPSG:4326` because these coordinates are longitude and latitude in decimal degrees. We will talk more about CRS later in the exercise and throughout the course.

# %%
sdekayi_gdf = gpd.GeoDataFrame(
    sdekayi_df,
    geometry=gpd.points_from_xy(sdekayi_df["Longitude"], sdekayi_df["Latitude"]),
    crs="EPSG:4326",
)
## This creates a new column labeled "geometry"

sdekayi_gdf["Species"] = "Storeria dekayi"

sdekayi_gdf.head()
# Out:
#           ID     Longitude     Latitude                    geometry  \
# 0  CAS162020     -79.53386     33.14123  POINT (-79.53386 33.14123)
# 1  CAS199805  -82.80616589  41.54882969  POINT (-82.80617 41.54883)
# 2  CAS210409  -79.24691667  41.18311667  POINT (-79.24692 41.18312)
# 3   OMNH2693     -94.52158     34.69291  POINT (-94.52158 34.69291)
# 4  OMNH12346    -97.449726     35.17868  POINT (-97.44973 35.17868)
#
#            Species
# 0  Storeria dekayi
# 1  Storeria dekayi
# 2  Storeria dekayi
# 3  Storeria dekayi
# 4  Storeria dekayi

# %% [markdown]
# ### Plot the first species
#
# geopandas geodataframes have a very useful function called `explore()` to plot the geometries on an interactive map. At this stage, we are mainly checking that the coordinates were read correctly and appear in a reasonable part of eastern North America.

# %%
sdekayi_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f0e90ef49d77bb2c91023373b47f073 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f0e90ef49d77bb2c91023373b47f073&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f0e90ef49d77bb2c91023373b47f073 = L.map(
#                 &quot;map_5f0e90ef49d77bb2c91023373b47f073&quot;,
#                 {
#                     center: [35.9416405, -86.976161],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5f0e90ef49d77bb2c91023373b47f073);
#
#
#
#
#
#             var tile_layer_ddd61c046b651053332a1ae9c6d4134c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ddd61c046b651053332a1ae9c6d4134c.addTo(map_5f0e90ef49d77bb2c91023373b47f073);
#
#
#             map_5f0e90ef49d77bb2c91023373b47f073.fitBounds(
#                 [[28.121591, -99.96245], [43.76169, -73.989872]],
#                 {}
#             );
#
#
#         function geo_json_5c82232a327487ef35d82d043f170312_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5c82232a327487ef35d82d043f170312_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5c82232a327487ef35d82d043f170312_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_5c82232a327487ef35d82d043f170312_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5c82232a327487ef35d82d043f170312_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5c82232a327487ef35d82d043f170312.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5c82232a327487ef35d82d043f170312_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5c82232a327487ef35d82d043f170312 = L.geoJson(null, {
#                 onEachFeature: geo_json_5c82232a327487ef35d82d043f170312_onEachFeature,
#
#                 style: geo_json_5c82232a327487ef35d82d043f170312_styler,
#                 pointToLayer: geo_json_5c82232a327487ef35d82d043f170312_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5c82232a327487ef35d82d043f170312_add (data) {
#             geo_json_5c82232a327487ef35d82d043f170312
#                 .addData(data);
#         }
#             geo_json_5c82232a327487ef35d82d043f170312_add({&quot;bbox&quot;: [-99.96245, 28.121591, -73.989872, 43.76169], &quot;features&quot;: [{&quot;bbox&quot;: [-79.53386, 33.14123, -79.53386, 33.14123], &quot;geometry&quot;: {&quot;coordinates&quot;: [-79.53386, 33.14123], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;ID&quot;: &quot;CAS162020&quot;, &quot;Latitude&quot;: &quot;33.14123&quot;, &quot;Longitude&quot;: &quot;-79.53386&quot;, &quot;Species&quot;: &quot;Storeria dekayi&

# %% [markdown]
# ### Load and plot a second species
#
# Now repeat the same workflow for eastern copperhead (*Agkistrodon contortrix*). Repeating the steps once by hand is useful practice before wrapping the workflow in a function.

# %%
acontortrix_csv = "EasternSnakes/Acontortrix_coords.csv"
acontortrix_df = gpd.read_file(acontortrix_csv)

acontortrix_gdf = gpd.GeoDataFrame(
    acontortrix_df,
    geometry=gpd.points_from_xy(acontortrix_df["Longitude"], acontortrix_df["Latitude"]),
    crs="EPSG:4326",
)
acontortrix_gdf["Species"] = "Agkistrodon contortrix"

acontortrix_gdf.head()
# Out:
#           ID     Longitude     Latitude                    geometry  \
# 0  CAS203553  -90.49508231  38.96836261  POINT (-90.49508 38.96836)
# 1  CAS203555  -90.91443611  37.92668333  POINT (-90.91444 37.92668)
# 2  CAS203566  -91.52694444  35.39361111  POINT (-91.52694 35.39361)
# 3  CAS203564     -90.46245  37.12165556  POINT (-90.46245 37.12166)
# 4   KU337018     -96.60919     39.10677  POINT (-96.60919 39.10677)
#
#                   Species
# 0  Agkistrodon contortrix
# 1  Agkistrodon contortrix
# 2  Agkistrodon contortrix
# 3  Agkistrodon contortrix
# 4  Agkistrodon contortrix

# %%
acontortrix_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec9eed3fa1b19283b3b1036469174963 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec9eed3fa1b19283b3b1036469174963&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec9eed3fa1b19283b3b1036469174963 = L.map(
#                 &quot;map_ec9eed3fa1b19283b3b1036469174963&quot;,
#                 {
#                     center: [34.806415, -86.812175],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ec9eed3fa1b19283b3b1036469174963);
#
#
#
#
#
#             var tile_layer_46ef24b965d6fc304810cdab6951ae9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46ef24b965d6fc304810cdab6951ae9e.addTo(map_ec9eed3fa1b19283b3b1036469174963);
#
#
#             map_ec9eed3fa1b19283b3b1036469174963.fitBounds(
#                 [[30.50606, -96.60919], [39.10677, -77.01516]],
#                 {}
#             );
#
#
#         function geo_json_71f04abb1ad0009def4f736849f3bce4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_71f04abb1ad0009def4f736849f3bce4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_71f04abb1ad0009def4f736849f3bce4_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_71f04abb1ad0009def4f736849f3bce4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_71f04abb1ad0009def4f736849f3bce4_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_71f04abb1ad0009def4f736849f3bce4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_71f04abb1ad0009def4f736849f3bce4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_71f04abb1ad0009def4f736849f3bce4 = L.geoJson(null, {
#                 onEachFeature: geo_json_71f04abb1ad0009def4f736849f3bce4_onEachFeature,
#
#                 style: geo_json_71f04abb1ad0009def4f736849f3bce4_styler,
#                 pointToLayer: geo_json_71f04abb1ad0009def4f736849f3bce4_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_71f04abb1ad0009def4f736849f3bce4_add (data) {
#             geo_json_71f04abb1ad0009def4f736849f3bce4
#                 .addData(data);
#         }
#             geo_json_71f04abb1ad0009def4f736849f3bce4_add({&quot;bbox&quot;: [-96.60919, 30.50606, -77.01516, 39.10677], &quot;features&quot;: [{&quot;bbox&quot;: [-90.49508231, 38.96836261, -90.49508231, 38.96836261], &quot;geometry&quot;: {&quot;coordinates&quot;: [-90.49508231, 38.96836261], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;ID&quot;: &quot;CAS203553&quot;, &quot;Latitude&quot;: &quot;38.96836261&quot;, &quot;Longitude&quot;: &quot;-90.49508231&quot;, &quot;Species&quot;: &qu

# %% [markdown]
# ### Merge the two GeoDataFrames
#
# Because both species tables have the same columns and the same CRS, we can stack them into one combined `GeoDataFrame` with `pd.concat`. Keeping a `Species` column lets us separate the records again later.

# %%
snakes_gdf = pd.concat([sdekayi_gdf, acontortrix_gdf])
snakes_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09f1bbfb1ab232e1849036d9346c970c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09f1bbfb1ab232e1849036d9346c970c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09f1bbfb1ab232e1849036d9346c970c = L.map(
#                 &quot;map_09f1bbfb1ab232e1849036d9346c970c&quot;,
#                 {
#                     center: [35.9416405, -86.976161],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_09f1bbfb1ab232e1849036d9346c970c);
#
#
#
#
#
#             var tile_layer_5150e2b3266ac7c4e3ba30daa3463cf0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5150e2b3266ac7c4e3ba30daa3463cf0.addTo(map_09f1bbfb1ab232e1849036d9346c970c);
#
#
#             map_09f1bbfb1ab232e1849036d9346c970c.fitBounds(
#                 [[28.121591, -99.96245], [43.76169, -73.989872]],
#                 {}
#             );
#
#
#         function geo_json_0274380a09057af72e4babbc4f4bf78c_styler(feature) {
#             switch(feature.properties.ID) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0274380a09057af72e4babbc4f4bf78c_highlighter(feature) {
#             switch(feature.properties.ID) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0274380a09057af72e4babbc4f4bf78c_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_0274380a09057af72e4babbc4f4bf78c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0274380a09057af72e4babbc4f4bf78c_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_0274380a09057af72e4babbc4f4bf78c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0274380a09057af72e4babbc4f4bf78c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0274380a09057af72e4babbc4f4bf78c = L.geoJson(null, {
#                 onEachFeature: geo_json_0274380a09057af72e4babbc4f4bf78c_onEachFeature,
#
#                 style: geo_json_0274380a09057af72e4babbc4f4bf78c_styler,
#                 pointToLayer: geo_json_0274380a09057af72e4babbc4f4bf78c_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_0274380a09057af72e4babbc4f4bf78c_add (data) {
#             geo_json_0274380a09057af72e4babbc4f4bf78c
#                 .addData(data);
#         }
#             geo_json_0274380a09057af72e4babbc4f4bf78c_add({&quot;bbox&quot;: [-99.96245, 28.121591, -73.989872, 43.76169], &quot;features&quot;: [{&quot;bbox&quot;: [-79.53386, 33.14123, -79.53386, 33.14123], &quot;geometry&quot;: {&quot;coordinates&quot;: [-79.53386, 33.14123], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;ID&quot;: &quot;CAS162020&quot;, &quot;Latitude&quot;: &quot;33.14123&quot;, &quot;Longitude&quot;: &quot;-79.53386&quot;, &quot;Species&quot;:

# %% [markdown]
# ### Color points by labels in a column
#
# The previous figure shows the sampling distribution of both species combined, but it uses the same color for all points, which isn't very useful. We can tell `gdf.explore()` which column we are interested in for differentiating points by passing in the species ID column.

# %%
snakes_gdf.explore(column="Species")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b690c87bc22197b2aab1c3a0bc5b4fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend Species&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;Species&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;Agkistrodon contortrix&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;Storeria dekayi&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b690c87bc22197b2aab1c3a0bc5b4fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b690c87bc22197b2aab1c3a0bc5b4fc = L.map(
#                 &quot;map_4b690c87bc22197b2aab1c3a0bc5b4fc&quot;,
#                 {
#                     center: [35.9416405, -86.976161],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4b690c87bc22197b2aab1c3a0bc5b4fc);
#
#
#
#
#
#             var tile_layer_e2b7c6a2e22053f2783ba20925bde583 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2b7c6a2e22053f2783ba20925bde583.addTo(map_4b690c87bc22197b2aab1c3a0bc5b4fc);
#
#
#             map_4b690c87bc22197b2aab1c3a0bc5b4fc.fitBounds(
#                 [[28.121591, -99.96245], [43.76169, -73.989872]],
#                 {}
#             );
#
#
#         function geo_json_f7b28f8fdcc0e066cc48a2e871ef6783_styler(feature) {
#             switch(feature.properties.ID) {
#                 case &quot;CAS162020&quot;: case &quot;CAS199805&quot;: case &quot;CAS210409&quot;: case &quot;OMNH2693&quot;: case &quot;OMNH12346&quot;: case &quot;OMNH15372&quot;: case &quot;OMNH5133&quot;: case &quot;UTEP21672&quot;: case &quot;YPM16611&quot;: case &quot;FHSM9980&quot;: case &quot;FHSM12731&quot;: case &quot;FHSM16847&quot;: case &quot;FHSM16947&quot;: case &quot;AMCC267207&quot;: case &quot;AMCC267212&quot;: case &quot;AMCC267199&quot;: case &quot;AMCC267200&quot;: case &quot;AMCC267201&quot;: case &quot;AMCC267202&quot;: case &quot;AMCC267203&quot;: case &quot;AMCC267205&quot;: case &quot;AMCC267206&quot;: case &quot;AMCC267209&quot;: case &quot;AMCC267210&quot;: case &quot;AMCC267211&quot;: case &quot;AMCC267213&qu

# %% [markdown]
# ### Choosing a color scheme
#
# geopandas picks a default color scheme which sometimes works, and sometimes not. Here it didn't work so well because the light blue of *Storeria dekayi* is somewhat difficult to see. You can set your own colormap with the `cmap` parameter. Let's choose `rainbow` which gives nice results for 2 species.
#
# You can see all the available colormaps in the [python colormap reference](https://matplotlib.org/stable/gallery/color/colormap_reference.html)

# %%
snakes_gdf.explore(column="Species", cmap="rainbow")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe3d6da81a2186f27a4eff1590d7d596 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend Species&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;Species&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8000ff&#x27;&gt;&lt;/span&gt;Agkistrodon contortrix&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0000&#x27;&gt;&lt;/span&gt;Storeria dekayi&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe3d6da81a2186f27a4eff1590d7d596&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe3d6da81a2186f27a4eff1590d7d596 = L.map(
#                 &quot;map_fe3d6da81a2186f27a4eff1590d7d596&quot;,
#                 {
#                     center: [35.9416405, -86.976161],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_fe3d6da81a2186f27a4eff1590d7d596);
#
#
#
#
#
#             var tile_layer_e133ce1423cb6c102ba50d42148251cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e133ce1423cb6c102ba50d42148251cf.addTo(map_fe3d6da81a2186f27a4eff1590d7d596);
#
#
#             map_fe3d6da81a2186f27a4eff1590d7d596.fitBounds(
#                 [[28.121591, -99.96245], [43.76169, -73.989872]],
#                 {}
#             );
#
#
#         function geo_json_f34270b8f4fe90e8fb1b9f330f08f6d7_styler(feature) {
#             switch(feature.properties.ID) {
#                 case &quot;CAS162020&quot;: case &quot;CAS199805&quot;: case &quot;CAS210409&quot;: case &quot;OMNH2693&quot;: case &quot;OMNH12346&quot;: case &quot;OMNH15372&quot;: case &quot;OMNH5133&quot;: case &quot;UTEP21672&quot;: case &quot;YPM16611&quot;: case &quot;FHSM9980&quot;: case &quot;FHSM12731&quot;: case &quot;FHSM16847&quot;: case &quot;FHSM16947&quot;: case &quot;AMCC267207&quot;: case &quot;AMCC267212&quot;: case &quot;AMCC267199&quot;: case &quot;AMCC267200&quot;: case &quot;AMCC267201&quot;: case &quot;AMCC267202&quot;: case &quot;AMCC267203&quot;: case &quot;AMCC267205&quot;: case &quot;AMCC267206&quot;: case &quot;AMCC267209&quot;: case &quot;AMCC267210&quot;: case &quot;AMCC267211&quot;: case &quot;AMCC267213&qu

# %% [markdown]
# ## A few basic spatial analyses
#
# Once the records are in one `GeoDataFrame`, we can ask simple spatial questions. The examples below are intentionally basic: count records, draw a simple hull around the occurrence records for each species, estimate the total geographic area of each species.
#
# For area e calculations, we first project the data from longitude/latitude into `EPSG:5070`, a projected CRS for North America with units in meters. Areas and distances in decimal degrees are hard to interpret, so this projection step matters.

# %%
# Count occurrence records for each species.
record_counts = snakes_gdf.groupby("Species").size()
record_counts
# Out:
# Species
# Agkistrodon contortrix    32
# Storeria dekayi           27
# dtype: int64

# %%
# Project the combined records before measuring areas.
snakes_projected = snakes_gdf.to_crs("EPSG:5070")
snakes_projected.crs
# Out:
# <Projected CRS: EPSG:5070>
# Name: NAD83 / Conus Albers
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - CONUS onshore - Alabama; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming.
# - bounds: (-124.79, 24.41, -66.91, 49.38)
# Coordinate Operation:
# - name: Conus Albers
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# Draw a simple convex hull around the records for each species.
# A convex hull is the smallest convex polygon that contains all points.
hulls_projected = snakes_projected.dissolve(by="Species").reset_index()

hulls_projected["geometry"] = hulls_projected.geometry.convex_hull

hulls = hulls_projected.to_crs(snakes_gdf.crs)

hulls.explore(column="Species", cmap="rainbow")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07fb14c2ff9b6c64428c9966c3cd8cfe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend Species&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;Species&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8000ff&#x27;&gt;&lt;/span&gt;Agkistrodon contortrix&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0000&#x27;&gt;&lt;/span&gt;Storeria dekayi&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07fb14c2ff9b6c64428c9966c3cd8cfe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07fb14c2ff9b6c64428c9966c3cd8cfe = L.map(
#                 &quot;map_07fb14c2ff9b6c64428c9966c3cd8cfe&quot;,
#                 {
#                     center: [35.941640500000005, -86.976161],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_07fb14c2ff9b6c64428c9966c3cd8cfe);
#
#
#
#
#
#             var tile_layer_81d2daf7e1c36de6619b1ad524930cc8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81d2daf7e1c36de6619b1ad524930cc8.addTo(map_07fb14c2ff9b6c64428c9966c3cd8cfe);
#
#
#             map_07fb14c2ff9b6c64428c9966c3cd8cfe.fitBounds(
#                 [[28.12159100000001, -99.96245], [43.761689999999994, -73.989872]],
#                 {}
#             );
#
#
#         function geo_json_fa0ace99eb757bf7b9487f0a02c13ba5_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#8000ff&quot;, &quot;fillColor&quot;: &quot;#8000ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#ff0000&quot;, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_fa0ace99eb757bf7b9487f0a02c13ba5_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_fa0ace99eb757bf7b9487f0a02c13ba5_pointToLayer(feature, latlng) {

# %% [markdown]
# ### Calculate the total area of the convex hull for each species
#
# Geopandas polygons have an `area` property that is measured in square meters, so we can convert this to square kilometers by dividing by 1,000,000

# %%
hulls["convex_hull_area_km2"] = hulls_projected.area / 1000000
hulls
# Out:
#                   Species                                           geometry  \
# 0  Agkistrodon contortrix  POLYGON ((-95.73278 30.66958, -96.60919 39.106...
# 1         Storeria dekayi  POLYGON ((-81.9901 28.12159, -95.04282 31.0772...
#
#           ID     Longitude     Latitude  convex_hull_area_km2
# 0  CAS203553  -90.49508231  38.96836261          1.333693e+06
# 1  CAS162020     -79.53386     33.14123          2.587939e+06

# %% [markdown]
# ### Practice submitting your work to your github
#
# Now that you have run through this exercise, practice submitting your notebook code to your class repo.
#
# Open a terminal window and run these commands to add, commit, and push your notebook:
#
# ```
# # Go to the labs directory in the course repo
# cd ~/BIO597-SpatialBiodiversity/docs/labs
#
# # Add your changed lab
# git add Lab01-IntroPython-Geopandas.ipynb
# git commit -m 'Finished Lab01'
# git push

# %% [markdown]
# EAM: I've finished Lab 01
